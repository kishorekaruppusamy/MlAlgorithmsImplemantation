# %%
import numpy as np
import pandas as pd
import re
import nltk
import spacy
import string

# %%
full_df = pd.read_csv("/Users/kishore-pt5635/Downloads/twcs.csv")

# %%
full_df.head()
# Out:
#    tweet_id   author_id  inbound                      created_at
# 0         1  sprintcare    False  Tue Oct 31 22:10:47 +0000 2017  \
# 1         2      115712     True  Tue Oct 31 22:11:45 +0000 2017
# 2         3      115712     True  Tue Oct 31 22:08:27 +0000 2017
# 3         4  sprintcare    False  Tue Oct 31 21:54:49 +0000 2017
# 4         5      115712     True  Tue Oct 31 21:49:35 +0000 2017
#
#                                                 text response_tweet_id
# 0  @115712 I understand. I would like to assist y...                 2  \
# 1      @sprintcare and how do you propose we do that               NaN
# 2  @sprintcare I have sent several private messag...                 1
# 3  @115712 Please send us a Private Message so th...                 3
# 4                                 @sprintcare I did.                 4
#
#    in_response_to_tweet_id
# 0                      3.0
# 1                      1.0
# 2                      4.0
# 3                      5.0
# ...

# %%
df_text = full_df[["text"]]

# %%
df_text["text"] = df_text["text"].astype(str)
# Out:
# /var/folders/ld/g28cnzf14pgfnzt1qwl4d8cmdnw91k/T/ipykernel_5798/2508898611.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_text["text"] = df_text["text"].astype(str)

# %%
df_text["text"]
# Out:
# 0          @115712 I understand. I would like to assist y...
# 1              @sprintcare and how do you propose we do that
# 2          @sprintcare I have sent several private messag...
# 3          @115712 Please send us a Private Message so th...
# 4                                         @sprintcare I did.
#                                  ...
# 2811769    @823869 Hey, we'd be happy to look into this f...
# 2811770    @115714 wtf!? I’ve been having really shitty s...
# 2811771    @143549 @sprintcare You have to go to https://...
# 2811772    @823870 Sounds delicious, Sarah! 😋 https://t.c...
# 2811773    @AldiUK  warm sloe gin mince pies with ice cre...
# Name: text, Length: 2811774, dtype: object

# %%
df_text["text_lower"] = df_text["text"].str.lower()
df_text.head()
# Out:
# /var/folders/ld/g28cnzf14pgfnzt1qwl4d8cmdnw91k/T/ipykernel_5798/1524063691.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_text["text_lower"] = df_text["text"].str.lower()
#                                                 text
# 0  @115712 I understand. I would like to assist y...  \
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare I have sent several private messag...
# 3  @115712 Please send us a Private Message so th...
# 4                                 @sprintcare I did.
#
#                                           text_lower
# 0  @115712 i understand. i would like to assist y...
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare i have sent several private messag...
# ...

# %%
PUNCTUATION_TO_REMOVE = string.punctuation

def remove_punctuation(text):
    return text.translate(str.maketrans('', '', PUNCTUATION_TO_REMOVE))

df_text["punc_removed"] = df_text["text_lower"].apply(lambda text: remove_punctuation(text))
df_text.head()
# Out:
# /var/folders/ld/g28cnzf14pgfnzt1qwl4d8cmdnw91k/T/ipykernel_5798/4159416020.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_text["punc_removed"] = df_text["text_lower"].apply(lambda text: remove_punctuation(text))
#                                                 text
# 0  @115712 I understand. I would like to assist y...  \
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare I have sent several private messag...
# 3  @115712 Please send us a Private Message so th...
# 4                                 @sprintcare I did.
#
#                                           text_lower
# 0  @115712 i understand. i would like to assist y...  \
# 1      @sprintcare and how do you propose we do that
# ...

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /Users/kishore-
# [nltk_data]     pt5635/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords
", ".join(stopwords.words("english"))
# Out:
# "i, me, my, myself, we, our, ours, ourselves, you, you're, you've, you'll, you'd, your, yours, yourself, yourselves, he, him, his, himself, she, she's, her, hers, herself, it, it's, its, itself, they, them, their, theirs, themselves, what, which, who, whom, this, that, that'll, these, those, am, is, are, was, were, be, been, being, have, has, had, having, do, does, did, doing, a, an, the, and, but, if, or, because, as, until, while, of, at, by, for, with, about, against, between, into, through, during, before, after, above, below, to, from, up, down, in, out, on, off, over, under, again, further, then, once, here, there, when, where, why, how, all, any, both, each, few, more, most, other, some, such, no, nor, not, only, own, same, so, than, too, very, s, t, can, will, just, don, don't, should, should've, now, d, ll, m, o, re, ve, y, ain, aren, aren't, couldn, couldn't, didn, didn't, doesn, doesn't, hadn, hadn't, hasn, hasn't, haven, haven't, isn, isn't, ma, mightn, mightn't, mustn, m
# ...

# %%
STOPWORDS = set(stopwords.words("english"))

def remove_stopwords(text):
    return " ".join([word for word in str(text).split() if word not in STOPWORDS])

df_text["stopword_removed"] = df_text["punc_removed"].apply(lambda text: remove_stopwords(text))
df_text.head()
# Out:
# /var/folders/ld/g28cnzf14pgfnzt1qwl4d8cmdnw91k/T/ipykernel_5798/1085426035.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_text["stopword_removed"] = df_text["punc_removed"].apply(lambda text: remove_stopwords(text))
#                                                 text
# 0  @115712 I understand. I would like to assist y...  \
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare I have sent several private messag...
# 3  @115712 Please send us a Private Message so th...
# 4                                 @sprintcare I did.
#
#                                           text_lower
# 0  @115712 i understand. i would like to assist y...  \
# 1      @sprintcare and how do you propose we do that
# ...

# %%
from nltk.stem.porter import PorterStemmer

stemmer = PorterStemmer()

def stem_words(text):
    return " ".join([stemmer.stem(word) for word in text.split()])

df_text["stemming"] = df_text["stopword_removed"].apply(lambda text: stem_words(text))
df_text.head()
# Out:
# /var/folders/ld/g28cnzf14pgfnzt1qwl4d8cmdnw91k/T/ipykernel_5798/1840912918.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_text["stemming"] = df_text["stopword_removed"].apply(lambda text: stem_words(text))
#                                                 text
# 0  @115712 I understand. I would like to assist y...  \
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare I have sent several private messag...
# 3  @115712 Please send us a Private Message so th...
# 4                                 @sprintcare I did.
#
#                                           text_lower
# 0  @115712 i understand. i would like to assist y...  \
# 1      @sprintcare and how do you propose we do that
# ...

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /Users/kishore-
# [nltk_data]     pt5635/nltk_data...
# True

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
def lemmatize_words(text):
    return " ".join([lemmatizer.lemmatize(word) for word in text.split()])

df_text["lemmatization"] = df_text["stopword_removed"].apply(lambda text: lemmatize_words(text))
df_text.head()
# Out:
# /var/folders/ld/g28cnzf14pgfnzt1qwl4d8cmdnw91k/T/ipykernel_5798/1116761488.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_text["lemmatization"] = df_text["stopword_removed"].apply(lambda text: lemmatize_words(text))
#                                                 text
# 0  @115712 I understand. I would like to assist y...  \
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare I have sent several private messag...
# 3  @115712 Please send us a Private Message so th...
# 4                                 @sprintcare I did.
#
#                                           text_lower
# 0  @115712 i understand. i would like to assist y...  \
# 1      @sprintcare and how do you propose we do that
# ...

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/kishore-pt5635/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
from nltk.corpus import wordnet
wordNet_map = {"N": wordnet.NOUN, "V": wordnet.VERB, "J": wordnet.ADJ, "R": wordnet.ADV}
def lemmatize_words_with_parts_of_speech(text):
    pos_tagged_text = nltk.pos_tag(text.split())
    return " ".join([lemmatizer.lemmatize(word, wordNet_map.get(pos[0], wordnet.NOUN)) for word, pos in pos_tagged_text])

df_text["lemmatization_with_pos"] = df_text["lemmatization"].apply(lambda text: lemmatize_words_with_parts_of_speech(text))
df_text.head()
# Out:
#                                                 text
# 0  @115712 I understand. I would like to assist y...  \
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare I have sent several private messag...
# 3  @115712 Please send us a Private Message so th...
# 4                                 @sprintcare I did.
#
#                                           text_lower
# 0  @115712 i understand. i would like to assist y...  \
# 1      @sprintcare and how do you propose we do that
# 2  @sprintcare i have sent several private messag...
# 3  @115712 please send us a private message so th...
# 4                                 @sprintcare i did.
#
#                                         punc_removed
# 0  115712 i understand i would like to assist you...  \
# 1       sprintcare and how do you propose we do that
# 2  sprintcare i have sent several private message...
# 3  115712 please send us a private message so tha...
# ...
